# %%
import pandas as pd  # Primary data handling
import numpy as np   # Numerical operations
import matplotlib.pyplot as plt  # Basic visualization
import seaborn as sns  # Advanced visualization

# %%
df = pd.read_csv('./data/va_facilities - va_facilities.csv')  # Replace with your file path

# %%
# Display the first few rows to understand the data
print("Original dataset shape:", df.shape)
# Out:
# Original dataset shape: (7998, 22)

# %%
# Check all locations in the dataset
print("\nUnique locations in the dataset:")
print(df['County/Parish'].value_counts())
# Out:
# Unique locations in the dataset:
# FAIRFAX              465
# RICHMOND CITY        372
# NORFOLK CITY         279
# PETERSBURG CITY      186
# JAMES CITY           186
#                     ...
# HARRISONBURG CITY     93
# DANVILLE CITY         93
# ALBEMARLE             93
# ESSEX                 93
# NEW KENT              93
# Name: County/Parish, Length: 65, dtype: int64

# %%
# Remove duplicates based on 'Facility Name' column
df_unique_facilities = df.drop_duplicates(subset=['Facility Name'])
df_unique_facilities
# Out:
#      Facility ID                                  Facility Name  \
# 0         490002                        RUSSELL COUNTY HOSPITAL
# 93        490004                     SENTARA RMH MEDICAL CENTER
# 186       490005                      WINCHESTER MEDICAL CENTER
# 279       490007               SENTARA NORFOLK GENERAL HOSPITAL
# 372       490009          UNIVERSITY OF VIRGINIA MEDICAL CENTER
# ...          ...                                            ...
# 7533      491307                    PAGE MEMORIAL HOSPITAL, INC
# 7626      491308                  RAPPAHANNOCK GENERAL HOSPITAL
# 7719      491309                  LEE COUNTY COMMUNITY HOSPITAL
# 7812      493300                        CUMBERLAND HOSPITAL LLC
# 7905      493301  CHILDRENS HOSPITAL OF THE KINGS DAUGHTERS INC
#
#                        Address        City/Town State  ZIP Code  \
# 0            58 CARROLL STREET          LEBANON    VA     24266
# 93    2010 HEALTH CAMPUS DRIVE     HARRISONBURG    VA     22801
# 186            1840 AMHERST ST       WINCHESTER    VA     22601
# 279             600 GRESHAM DR          NORFOLK    VA     23507
# 372            1215 LEE STREET  CHARLOTTESVILLE    VA     22908
# ...                        ...              ...   ...       ...
# 7533        200 MEMORIAL DRIVE            LURAY    VA     22835
# 7626           101 HARRIS ROAD       KILMARNOCK    VA     22482
# 7719     127 HEALTH CARE DRIVE   PENNINGTON GAP    VA     24277
# 7812      9407 CUMBERLAND ROAD         NEW KENT    VA     23124
# 7905       601 CHILDREN'S LANE          NORFOLK    VA     23507
#
#              County/Parish Telephone Number HCAHPS Measure ID  \
# 0                  RUSSELL   (276) 883-8100      H_COMP_1_A_P
# 93       HARRISONBURG CITY   (540) 689-1000      H_COMP_1_A_P
# 186        WINCHESTER CITY   (540) 536-8000      H_COMP_1_A_P
# 279           NORFOLK CITY   (757) 388-3000      H_COMP_1_A_P
# 372   CHARLOTTESVILLE CITY   (434) 924-0000      H_COMP_1_A_P
# ...                    ...              ...               ...
# 7533                  PAGE   (540) 743-4561      H_COMP_1_A_P
# 7626             LANCASTER   (804) 435-8000      H_COMP_1_A_P
# 7719                   LEE   (276) 299-5000      H_COMP_1_A_P
# 7812              NEW KENT   (804) 966-2242      H_COMP_1_A_P
# 7905          NORFOLK CITY   (757) 668-9647      H_COMP_1_A_P
#
#                                         HCAHPS Question  ...  \
# 0     Patients who reported that their nurses "Alway...  ...
# 93    Patients who reported that their nurses "Alway...  ...
# 186   Patients who reported that their nurses "Alway...  ...
# 279   Patients who reported that their nurses "Alway...  ...
# 372   Patients who reported that their nurses "Alway...  ...
# ...                                                 ...  ...
# 7533  Patients who reported that their nurses "Alway...  ...
# 7626  Patients who reported that their nurses "Alway...  ...
# 7719  Patients who reported that their nurses "Alway...  ...
# 7812  Patients who reported that their nurses "Alway...  ...
# 7905  Patients who reported that their nurses "Alway...  ...
#
#      Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 0                                    NaN                    90
# 93                                   NaN                    77
# 186                                  NaN                    80
# 279                                  NaN                    79
# 372                                  NaN                    80
# ...                                  ...                   ...
# 7533                                 NaN                    84
# 7626                                 NaN                    86
# 7719                                 NaN                    93
# 7812                                 NaN         Not Available
# 7905                                 NaN         Not Available
#
#       HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 0                                NaN           Not Applicable
# 93                               NaN           Not Applicable
# 186                              NaN           Not Applicable
# 279                              NaN           Not Applicable
# 372                              NaN           Not Applicable
# ...                              ...                      ...
# 7533                             NaN           Not Applicable
# 7626                             NaN           Not Applicable
# 7719                            10.0           Not Applicable
# 7812                            19.0           Not Applicable
# 7905                            19.0           Not Applicable
#
#       Number of Completed Surveys Number of Completed Surveys Footnote  \
# 0                             135                                  NaN
# 93                            584                                  NaN
# 186                           966                                  NaN
# 279                           762                                  NaN
# 372                          1055                                  NaN
# ...                           ...                                  ...
# 7533                          145                                  NaN
# 7626                          103                                  NaN
# 7719                           37                                 10.0
# 7812                Not Available                                 19.0
# 7905                Not Available                                 19.0
#
#      Survey Response Rate Percent  Survey Response Rate Percent Footnote  \
# 0                              19                                    NaN
# 93                             25                                    NaN
# 186                            24                                    NaN
# 279                            19                                    NaN
# 372                            21                                    NaN
# ...                           ...                                    ...
# 7533                           26                                    NaN
# 7626                           27                                    NaN
# 7719                           24                                   10.0
# 7812                Not Available                                   19.0
# 7905                Not Available                                   19.0
#
#       Start Date    End Date
# 0     04/01/2023  03/31/2024
# 93    04/01/2023  03/31/2024
# 186   04/01/2023  03/31/2024
# 279   04/01/2023  03/31/2024
# 372   04/01/2023  03/31/2024
# ...          ...         ...
# 7533  04/01/2023  03/31/2024
# 7626  04/01/2023  03/31/2024
# 7719  04/01/2023  03/31/2024
# 7812  04/01/2023  03/31/2024
# 7905  04/01/2023  03/31/2024
#
# [86 rows x 22 columns]

# %%
# maryland_df = df[
#     (df['County/Parish'] == "Prince Georges") |
#     (df['County/Parish'] == "Montgomery") |
#     (df['County/Parish'] == "Anne Arundel") |
#     (df['County/Parish'] == "Charles")
# ]

va_df = df[
    # (df['County/Parish'] == "Fairfax City") |
    (df['County/Parish'] == "ARLINGTON") |
    (df['County/Parish'] == "FAIRFAX") 
]

# %%
# If you want unique facilities in those locations:
filtered_unique_df = va_df.drop_duplicates(subset=['Facility Name'])

# %%
# Display the results
print(filtered_unique_df)
# Out:
#      Facility ID                    Facility Name  \
# 837       49001F  Fort Belvoir Community Hospital
# 2511      490050         VIRGINIA HOSPITAL CENTER
# 3069      490063           INOVA FAIRFAX HOSPITAL
# 4650      490101         INOVA FAIR OAKS HOSPITAL
# 4836      490107           RESTON HOSPITAL CENTER
# 6138      490122      INOVA MOUNT VERNON HOSPITAL
#
#                             Address     City/Town State  ZIP Code  \
# 837                9300 DeWitt Loop  Fort Belvoir    VA     22060
# 2511  1701 NORTH GEORGE MASON DRIVE     ARLINGTON    VA     22205
# 3069              3300 GALLOWS ROAD  FALLS CHURCH    VA     22042
# 4650      3600 JOSEPH SIEWICK DRIVE       FAIRFAX    VA     22033
# 4836       1850 TOWN CENTER PARKWAY        RESTON    VA     20190
# 6138              2501 PARKERS LANE    ALEXANDRIA    VA     22306
#
#      County/Parish Telephone Number HCAHPS Measure ID  \
# 837        FAIRFAX   (571) 231-3224      H_COMP_1_A_P
# 2511     ARLINGTON   (703) 558-5000      H_COMP_1_A_P
# 3069       FAIRFAX   (703) 776-4001      H_COMP_1_A_P
# 4650       FAIRFAX   (703) 391-4170      H_COMP_1_A_P
# 4836       FAIRFAX   (703) 689-9000      H_COMP_1_A_P
# 6138       FAIRFAX   (703) 664-7000      H_COMP_1_A_P
#
#                                         HCAHPS Question  ...  \
# 837   Patients who reported that their nurses "Alway...  ...
# 2511  Patients who reported that their nurses "Alway...  ...
# 3069  Patients who reported that their nurses "Alway...  ...
# 4650  Patients who reported that their nurses "Alway...  ...
# 4836  Patients who reported that their nurses "Alway...  ...
# 6138  Patients who reported that their nurses "Alway...  ...
#
#      Patient Survey Star Rating Footnote HCAHPS Answer Percent  \
# 837                                  NaN                    86
# 2511                                 NaN                    78
# 3069                                 NaN                    80
# 4650                                 NaN                    76
# 4836                                 NaN                    71
# 6138                                 NaN                    73
#
#       HCAHPS Answer Percent Footnote HCAHPS Linear Mean Value  \
# 837                              NaN           Not Applicable
# 2511                             NaN           Not Applicable
# 3069                             NaN           Not Applicable
# 4650                             NaN           Not Applicable
# 4836                             NaN           Not Applicable
# 6138                             NaN           Not Applicable
#
#       Number of Completed Surveys Number of Completed Surveys Footnote  \
# 837                           809                                  NaN
# 2511                         2061                                  NaN
# 3069                          679                                  NaN
# 4650                          512                                  NaN
# 4836                          510                                  NaN
# 6138                          350                                  NaN
#
#      Survey Response Rate Percent  Survey Response Rate Percent Footnote  \
# 837                            31                                    NaN
# 2511                           21                                    NaN
# 3069                           19                                    NaN
# 4650                           15                                    NaN
# 4836                           20                                    NaN
# 6138                           19                                    NaN
#
#       Start Date    End Date
# 837   04/01/2023  03/31/2024
# 2511  04/01/2023  03/31/2024
# 3069  04/01/2023  03/31/2024
# 4650  04/01/2023  03/31/2024
# 4836  04/01/2023  03/31/2024
# 6138  04/01/2023  03/31/2024
#
# [6 rows x 22 columns]

# %%
# Optional: Save the filtered dataset to a new CSV file
filtered_unique_df.to_csv('./data/va_facilities - va_facilities.csv', index=False)
