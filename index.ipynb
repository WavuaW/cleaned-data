# %%
import pandas as pd  # Primary data handling
import numpy as np   # Numerical operations
import matplotlib.pyplot as plt  # Basic visualization
import seaborn as sns  # Advanced visualization

# %%
df = pd.read_csv('./data/Nursing_Homes_facilities_MD - md2_facilities.csv')  # Replace with your file path

# %%
# Display the first few rows to understand the data
print("Original dataset shape:", df.shape)
# Out:
# Original dataset shape: (222, 103)

# %%
# Check all locations in the dataset
print("\nUnique locations in the dataset:")
print(df['County/Parish'].value_counts())
# Out:
# Unique locations in the dataset:
# Baltimore         44
# Montgomery        34
# Baltimore City    27
# Prince Georges    19
# Anne Arundel      14
# Carroll           10
# Washington        10
# Frederick          8
# Allegany           8
# Howard             6
# Harford            6
# Wicomico           4
# Garrett            4
# Charles            4
# Calvert            3
# Worcester          3
# Kent               3
# Cecil              3
# St. Marys          3
# Caroline           2
# Dorchester         2
# Talbot             2
# Somerset           2
# Queen Annes        1
# Name: County/Parish, dtype: int64

# %%
# Remove duplicates based on 'Facility Name' column
df_unique_facilities = df.drop_duplicates(subset=['Provider Name'])
df_unique_facilities
# Out:
#      CMS Certification Number (CCN)  \
# 0                      2.150010e+05
# 1                      2.150050e+05
# 2                      2.150070e+05
# 3                      2.150100e+05
# 4                      2.150130e+05
# ..                              ...
# 217                    2.153640e+05
# 218                    2.153650e+05
# 219                    2.153720e+05
# 220                    2.100000e+10
# 221                   2.100000e+105
#
#                                  Provider Name         Provider Address  \
# 0    AUTUMN LAKE HEALTHCARE AT BALLENGER CREEK      347 BALLENGER DRIVE
# 1                   COMPLETE CARE AT ANNAPOLIS     900 VAN BUREN STREET
# 2                        WICOMICO NURSING HOME         900 BOOTH STREET
# 3                      PINES NURSING AND REHAB      610 DUTCHMAN'S LANE
# 4                ST. MARY'S NURSING CENTER INC     21585 PEABODY STREET
# ..                                         ...                      ...
# 217                 FUTURE CARE CAPITAL REGION     1051 BRIGHTSEAT ROAD
# 218                COMPLETE CARE AT HAGERSTOWN         14014 MARSH PIKE
# 219                                   EDENWALD       800 SOUTHERLY ROAD
# 220                      SACRED HEART HOME INC  5805 QUEENS CHAPEL ROAD
# 221                ST. JOSEPH'S  NURSING  HOME       1222 TUGWELL DRIVE
#
#        City/Town State  ZIP Code  Telephone Number  Provider SSA County Code  \
# 0      FREDERICK    MD     21701        3016635181                       100
# 1      ANNAPOLIS    MD     21403        4102678653                        10
# 2      SALISBURY    MD     21801        4107428896                       220
# 3         EASTON    MD     21601        4108224000                       200
# 4    LEONARDTOWN    MD     20650        3014758000                       180
# ..           ...   ...       ...               ...                       ...
# 217     LANDOVER    MD     20785        2404874400                       160
# 218   HAGERSTOWN    MD     21742        3017338700                       210
# 219       TOWSON    MD     21286        4106168809                        20
# 220  HYATTSVILLE    MD     20782        3012776500                       160
# 221  CATONSVILLE    MD     21228        4107470026                        20
#
#       County/Parish                          Ownership Type  ...  \
# 0         Frederick  For profit - Limited Liability company  ...
# 1      Anne Arundel                For profit - Corporation  ...
# 2          Wicomico                     Government - County  ...
# 3            Talbot                For profit - Corporation  ...
# 4         St. Marys                Non profit - Corporation  ...
# ..              ...                                     ...  ...
# 217  Prince Georges  For profit - Limited Liability company  ...
# 218      Washington                For profit - Corporation  ...
# 219       Baltimore                Non profit - Corporation  ...
# 220  Prince Georges                Non profit - Corporation  ...
# 221       Baltimore             Non profit - Church related  ...
#
#      Number of Citations from Infection Control Inspections  Number of Fines  \
# 0                                                  NaN                     1
# 1                                                  NaN                     0
# 2                                                  NaN                     0
# 3                                                  NaN                     1
# 4                                                  NaN                     0
# ..                                                 ...                   ...
# 217                                                NaN                     0
# 218                                                NaN                     0
# 219                                                NaN                     0
# 220                                                NaN                     0
# 221                                                NaN                     0
#
#      Total Amount of Fines in Dollars Number of Payment Denials  \
# 0                            81025.75                         1
# 1                                0.00                         0
# 2                                0.00                         0
# 3                           172724.50                         1
# 4                                0.00                         0
# ..                                ...                       ...
# 217                              0.00                         0
# 218                              0.00                         0
# 219                              0.00                         0
# 220                              0.00                         0
# 221                              0.00                         0
#
#     Total Number of Penalties                                      Location  \
# 0                           2        347 BALLENGER DRIVE,FREDERICK,MD,21701
# 1                           0       900 VAN BUREN STREET,ANNAPOLIS,MD,21403
# 2                           0           900 BOOTH STREET,SALISBURY,MD,21801
# 3                           2           610 DUTCHMAN'S LANE,EASTON,MD,21601
# 4                           0     21585 PEABODY STREET,LEONARDTOWN,MD,20650
# ..                        ...                                           ...
# 217                         0        1051 BRIGHTSEAT ROAD,LANDOVER,MD,20785
# 218                         0          14014 MARSH PIKE,HAGERSTOWN,MD,21742
# 219                         0            800 SOUTHERLY ROAD,TOWSON,MD,21286
# 220                         0  5805 QUEENS CHAPEL ROAD,HYATTSVILLE,MD,20782
# 221                         0       1222 TUGWELL DRIVE,CATONSVILLE,MD,21228
#
#     Latitude Longitude  Geocoding Footnote Processing Date
# 0    39.4183   -77.336                22.0      2025-03-01
# 1    38.9616   -76.490                 NaN      2025-03-01
# 2    38.3772   -75.615                 NaN      2025-03-01
# 3    38.7597   -76.063                 NaN      2025-03-01
# 4    38.2992   -76.636                 NaN      2025-03-01
# ..       ...       ...                 ...             ...
# 217  38.9043   -76.853                 NaN      2025-03-01
# 218  39.7013   -77.686                 NaN      2025-03-01
# 219  39.4068   -76.599                 NaN      2025-03-01
# 220  38.9587   -76.958                 NaN      2025-03-01
# 221  39.2581   -76.738                 NaN      2025-03-01
#
# [222 rows x 103 columns]

# %%
maryland_df = df[
    (df['County/Parish'] == "Prince Georges") |
    (df['County/Parish'] == "Montgomery") |
    (df['County/Parish'] == "Anne Arundel") |
    (df['County/Parish'] == "Charles")
]

# %%
# If you want unique facilities in those locations:
filtered_unique_df = maryland_df.drop_duplicates(subset=['Provider Name'])

# %%
# Display the results
print(filtered_unique_df)
# Out:
#      CMS Certification Number (CCN)  \
# 1                      2.150050e+05
# 5                      2.150140e+05
# 6                      2.150150e+05
# 8                      2.150200e+05
# 10                     2.150240e+05
# ..                              ...
# 204                    2.153500e+05
# 207                    2.153530e+05
# 215                    2.153620e+05
# 217                    2.153640e+05
# 220                    2.100000e+10
#
#                                    Provider Name           Provider Address  \
# 1                     COMPLETE CARE AT ANNAPOLIS       900 VAN BUREN STREET
# 5               AUTUMN LAKE HEALTHCARE AT ARCOLA          901 ARCOLA AVENUE
# 6                                FAIRLAND CENTER         2101 FAIRLAND ROAD
# 8                  FORESTVILLE HEALTHCARE CENTER         7420 MARLBORO PIKE
# 10   WHITE OAK REHABILITATION AND NURSING CENTER            6500 RIGGS ROAD
# ..                                           ...                        ...
# 204   VILLA ROSA NURSING AND REHABILITATION, LLC  3800 LOTTSFORD VISTA ROAD
# 207                       INGLESIDE AT KING FARM    701 KING FARM BOULEVARD
# 215         RESTORE HEALTH REHABILITATION CENTER        4615 EINSTEIN PLACE
# 217                   FUTURE CARE CAPITAL REGION       1051 BRIGHTSEAT ROAD
# 220                        SACRED HEART HOME INC    5805 QUEENS CHAPEL ROAD
#
#          City/Town State  ZIP Code  Telephone Number  \
# 1        ANNAPOLIS    MD     21403        4102678653
# 5    SILVER SPRING    MD     20902        3016492400
# 6    SILVER SPRING    MD     20904        3013846161
# 8      FORESTVILLE    MD     20747        3017360240
# 10     HYATTSVILLE    MD     20783        3015590300
# ..             ...   ...       ...               ...
# 204  MITCHELLVILLE    MD     20721        3014594700
# 207      ROCKVILLE    MD     20850        2404999015
# 215   WHITE PLAINS    MD     20695        2404482000
# 217       LANDOVER    MD     20785        2404874400
# 220    HYATTSVILLE    MD     20782        3012776500
#
#      Provider SSA County Code   County/Parish  \
# 1                          10    Anne Arundel
# 5                         150      Montgomery
# 6                         150      Montgomery
# 8                         160  Prince Georges
# 10                        160  Prince Georges
# ..                        ...             ...
# 204                       160  Prince Georges
# 207                       150      Montgomery
# 215                        80         Charles
# 217                       160  Prince Georges
# 220                       160  Prince Georges
#
#                              Ownership Type  ...  \
# 1                  For profit - Corporation  ...
# 5                  For profit - Corporation  ...
# 6    For profit - Limited Liability company  ...
# 8                  For profit - Corporation  ...
# 10                 For profit - Corporation  ...
# ..                                      ...  ...
# 204  For profit - Limited Liability company  ...
# 207                Non profit - Corporation  ...
# 215                For profit - Corporation  ...
# 217  For profit - Limited Liability company  ...
# 220                Non profit - Corporation  ...
#
#      Number of Citations from Infection Control Inspections  Number of Fines  \
# 1                                                  NaN                     0
# 5                                                  NaN                     0
# 6                                                  NaN                     0
# 8                                                  NaN                     1
# 10                                                 NaN                     1
# ..                                                 ...                   ...
# 204                                                NaN                     0
# 207                                                NaN                     1
# 215                                                3.0                     1
# 217                                                NaN                     0
# 220                                                NaN                     0
#
#      Total Amount of Fines in Dollars Number of Payment Denials  \
# 1                                0.00                         0
# 5                                0.00                         0
# 6                                0.00                         0
# 8                            16038.75                         0
# 10                           11921.00                         0
# ..                                ...                       ...
# 204                              0.00                         0
# 207                            986.70                         0
# 215                          59169.50                         0
# 217                              0.00                         0
# 220                              0.00                         0
#
#     Total Number of Penalties  \
# 1                           0
# 5                           0
# 6                           0
# 8                           1
# 10                          1
# ..                        ...
# 204                         0
# 207                         1
# 215                         1
# 217                         0
# 220                         0
#
#                                              Location Latitude Longitude  \
# 1             900 VAN BUREN STREET,ANNAPOLIS,MD,21403  38.9616   -76.490
# 5            901 ARCOLA AVENUE,SILVER SPRING,MD,20902  39.0356   -77.026
# 6           2101 FAIRLAND ROAD,SILVER SPRING,MD,20904  39.0771   -76.968
# 8             7420 MARLBORO PIKE,FORESTVILLE,MD,20747  38.8481   -76.879
# 10               6500 RIGGS ROAD,HYATTSVILLE,MD,20783  38.9692   -76.985
# ..                                                ...      ...       ...
# 204  3800 LOTTSFORD VISTA ROAD,MITCHELLVILLE,MD,20721  38.9425   -76.825
# 207        701 KING FARM BOULEVARD,ROCKVILLE,MD,20850  39.1120   -77.177
# 215         4615 EINSTEIN PLACE,WHITE PLAINS,MD,20695  38.5926   -76.957
# 217            1051 BRIGHTSEAT ROAD,LANDOVER,MD,20785  38.9043   -76.853
# 220      5805 QUEENS CHAPEL ROAD,HYATTSVILLE,MD,20782  38.9587   -76.958
#
#      Geocoding Footnote Processing Date
# 1                   NaN      2025-03-01
# 5                   NaN      2025-03-01
# 6                   NaN      2025-03-01
# 8                   NaN      2025-03-01
# 10                  NaN      2025-03-01
# ..                  ...             ...
# 204                 NaN      2025-03-01
# 207                 NaN      2025-03-01
# 215                22.0      2025-03-01
# 217                 NaN      2025-03-01
# 220                 NaN      2025-03-01
#
# [71 rows x 103 columns]

# %%
# Optional: Save the filtered dataset to a new CSV file
filtered_unique_df.to_csv('./data/Nursing_Homes_facilities_MD - md2_facilities.csv', index=False)
